# %%
import sys
print(sys.executable)
# Out:
# /Users/sangmin/Desktop/personal/mockup/AI_Chat_mockup_Base/.venv/bin/python

# %%
# API 키를 환경변수로 관리하기 위한 설정 파일
from dotenv import load_dotenv

# API 키 정보 로드
load_dotenv()
# Out:
# True

# %%
from langchain_core.prompts import ChatPromptTemplate

# 프롬프트 생성
# 프롬프트는 에이전트에게 모델이 수행할 작업을 설명하는 텍스트를 제공합니다. (도구의 이름과 역할을 입력)
prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "You are a helpful assistant. "
            "Make sure to use the `search_news` tool for searching keyword related news.",
        ),
        ("placeholder", "{chat_history}"),
        ("human", "{input}"),
        ("placeholder", "{agent_scratchpad}"),
    ]
)
# Out:
# /Users/sangmin/Desktop/personal/mockup/AI_Chat_mockup_Base/.venv/lib/python3.14/site-packages/langchain_core/_api/deprecation.py:26: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1

# %%
# Ensure the local package is installed in editable mode so `app` can be imported.
# %pip install -e .

import sys
from pathlib import Path

proj_root = Path.cwd()
base_dir = proj_root.parent.parent  # Go up two levels to reach the project root
if str(base_dir) not in sys.path:
	sys.path.insert(0, str(base_dir))

from app.mcp.mcp_adapter_client import MCPAdapterClient
# from langchain_core.agents import initialize_agent

mcpclient = MCPAdapterClient()
 # Use the correct attribute or property
# Out:
# Obtaining file:///Users/sangmin/Desktop/personal/mockup/AI_Chat_mockup_Base/app/tests
# ERROR: file:///Users/sangmin/Desktop/personal/mockup/AI_Chat_mockup_Base/app/tests does not appear to be a Python project: neither 'setup.py' nor 'pyproject.toml' found.
# Note: you may need to restart the kernel to use updated packages.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 16
#      13 # from langchain_core.agents import initialize_agent
#      15 mcpclient = MCPAdapterClient()
# ---> 16 tools = mcpclient.tools  # Use the correct attribute or property
#
# AttributeError: 'MCPAdapterClient' object has no attribute 'tools'

# %%
# from langchain_openai import ChatOpenAI
# from langchain.agents import create_tool_calling_agent
# from app.utils import call_llm_stream, _get_openai_client
# LLM 정의

llm = call_llm_stream()

llm.invoke("Hello, world!")
# Agent 생성
# agent = create_tool_calling_agent(llm, tools, prompt)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 3
#       1 # from langchain_openai import ChatOpenAI
#       2 # from langchain.agents import create_tool_calling_agent
# ----> 3 from app.utils import call_llm_stream, _get_openai_client
#       4 # LLM 정의
#       6 llm = call_llm_stream()
#
# ModuleNotFoundError: No module named 'app'

# %%
from langchain_openai import ChatOpenAI
from langchain.agents import create_tool_calling_agent

# LLM 정의
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)

# Agent 생성
agent = create_tool_calling_agent(llm, tools, prompt)

# %%
from langchain.agents import AgentExecutor

# AgentExecutor 생성
agent_executor = AgentExecutor(
    agent=agent,
    tools=tools,
    verbose=True,
    max_iterations=10,
    max_execution_time=10,
    handle_parsing_errors=True,
)

# AgentExecutor 실행
result = agent_executor.invoke({"input": "AI 투자와 관련된 뉴스를 검색해 주세요."})

print("Agent 실행 결과:")
print(result["output"])
